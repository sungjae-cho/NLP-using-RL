# %% [markdown]
# # Assignment 2: Solve the Mountain Car Task

# %% [markdown]
# ## How to Do Assignment 2 (Official)
# - Solve the Mountain Car task in Gym environment.
# - Freely choose a control algorithm you prefer.
# - Study existing codes using the method you are following.
#   - [Mountain Car](https://github.com/Youngsam/youngsam.github.io/tree/master/codes/FunctionApprox/mountain_car)
# - Zip the **source code** and **result graph file**, and upload the file in ETL homework page (see the example in the lecture slide)
#
# **About the Result Graph**
# - x-axis: Episode
# - y-axis: Steps per episode (log scale. Averaged over 100 runs.)
# - You don’t need to test several parameters.
# - You don’t need to use log scale.
# - You better average the steps per episode for stable estimates (e.g., averaging over 10 runs).

# %% [markdown]
# ## References
# - [Original source](https://github.com/dennybritz/reinforcement-learning/tree/master/FA) of the given Mountain Car code.
# - [About MountainCar-v0](https://github.com/openai/gym/wiki/MountainCar-v0)

# %% [markdown]
# ## 1. Implementation of a Q-Learning Agent

# %%
"""
An easy-to-follow script to train, test and evaluate a Q-learning agent on the Mountain Car
problem using the OpenAI Gym.
This is part of the Book on "Getting started with OpenAI Gym"
Author: Praveen Palanisamy
"""
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

MAX_NUM_EPISODES = 300000
STEPS_PER_EPISODE = 200 #200 #  This is specific to MountainCar. May change with env
PRINT_PERIOD = MAX_NUM_EPISODES // 50 # unit: episodes
EPSILON_MIN = 0.005
max_num_steps = MAX_NUM_EPISODES * STEPS_PER_EPISODE
EPSILON_DECAY = 500 * EPSILON_MIN / max_num_steps
ALPHA = 0.05  # Learning rate
GAMMA = 0.98  # Discount factor
NUM_DISCRETE_BINS = 30  # Number of bins to Discretize each observation dim

class Q_Learner(object):
    def __init__(self, env):
        self.obs_shape = env.observation_space.shape
        self.obs_high = env.observation_space.high
        self.obs_low = env.observation_space.low
        self.obs_bins = NUM_DISCRETE_BINS  # Number of bins to Discretize each observation dim
        self.bin_width = (self.obs_high - self.obs_low) / self.obs_bins
        self.action_shape = env.action_space.n
        # Create a multi-dimensional array (aka. Table) to represent the
        # Q-values
        self.Q = np.zeros((self.obs_bins + 1, self.obs_bins + 1,
                           self.action_shape))  # (51 x 51 x 3)
        self.alpha = ALPHA  # Learning rate
        self.gamma = GAMMA  # Discount factor
        self.epsilon = 1.0
        

    def discretize(self, obs):
        return tuple(((obs - self.obs_low) / self.bin_width).astype(int))

    def get_action(self, obs):
        discretized_obs = self.discretize(obs)
        # Epsilon-Greedy action selection
        if self.epsilon > EPSILON_MIN:
            self.epsilon -= EPSILON_DECAY
        if np.random.random() > self.epsilon:
            return np.argmax(self.Q[discretized_obs])
        else:  # Choose a random action
            return np.random.choice([a for a in range(self.action_shape)])

    def learn(self, obs, action, reward, next_obs):
        discretized_obs = self.discretize(obs)
        discretized_next_obs = self.discretize(next_obs)
        td_target = reward + self.gamma * np.max(self.Q[discretized_next_obs])
        td_error = td_target - self.Q[discretized_obs][action]
        self.Q[discretized_obs][action] += self.alpha * td_error

def train(agent, env):
    best_reward = -float('inf')
    steps_list = list()
    
    for episode in range(MAX_NUM_EPISODES):
        done = False
        obs = env.reset()
        total_reward = 0.0
        steps = 0
        while not done:
            action = agent.get_action(obs)
            next_obs, reward, done, info = env.step(action)
            agent.learn(obs, action, reward, next_obs)
            obs = next_obs
            total_reward += reward
            steps = steps + 1
        if total_reward > best_reward:
            best_reward = total_reward
        
        if (episode % PRINT_PERIOD == 0) or (episode == MAX_NUM_EPISODES - 1):
            print("Episode#:{} reward:{} best_reward:{} epsilon:{}".format(episode,
                                         total_reward, best_reward, agent.epsilon))        
        
        steps_list.append(steps)
    # Return the trained policy
    return np.argmax(agent.Q, axis=2), steps_list


def test(agent, env, policy):
    done = False
    obs = env.reset()
    total_reward = 0.0
    while not done:
        action = policy[agent.discretize(obs)]
        next_obs, reward, done, info = env.step(action)
        obs = next_obs
        total_reward += reward
    return total_reward

def get_avg_steps_list(steps_list, steps):
    avg_steps_list = list()
    for i in range(len(steps_list) - steps + 1):
        mean = sum(steps_list[i:(i+steps)]) / steps
        avg_steps_list.append(mean)
    return avg_steps_list

# %% [markdown]
# ## 2. Visualization

# %% [markdown]
# ### 2.1. Training: Q-Learning

# %%
env = gym.make('MountainCar-v0')
agent = Q_Learner(env)
learned_policy, steps_list = train(agent, env)
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode#:0 reward:-200.0 best_reward:-200.0 epsilon:0.9999916666666655
# Episode#:6000 reward:-200.0 best_reward:-200.0 epsilon:0.9499916666596766
# Episode#:12000 reward:-200.0 best_reward:-200.0 epsilon:0.8999916666526877
# Episode#:18000 reward:-200.0 best_reward:-200.0 epsilon:0.8499916666456988
# Episode#:24000 reward:-200.0 best_reward:-200.0 epsilon:0.7999916666387099
# Episode#:30000 reward:-200.0 best_reward:-200.0 epsilon:0.749991666631721
# Episode#:36000 reward:-200.0 best_reward:-200.0 epsilon:0.6999916666247321
# Episode#:42000 reward:-200.0 best_reward:-194.0 epsilon:0.6499919166177432
# Episode#:48000 reward:-200.0 best_reward:-165.0 epsilon:0.6000130416107573
# Episode#:54000 reward:-200.0 best_reward:-153.0 epsilon:0.5501765416037913
# Episode#:60000 reward:-200.0 best_reward:-152.0 epsilon:0.5007608332635507
# Episode#:66000 reward:-200.0 best_reward:-144.0 epsilon:0.45214983325675595
# Episode#:72000 reward:-200.0 best_reward:-116.0 epsilon:0.40492904158348886
# Episode#:78000 reward:-160.0 best_reward:-116.0 epsilon:0.35893424991039313
# Episode#:84000 reward:-192.0 best_reward:-116.0 epsilon:0.3146402499042018
# Episode#:90000 reward:-200.0 best_reward:-113.0 epsilon:0.27175324989820715
# Episode#:96000 reward:-151.0 best_reward:-111.0 epsilon:0.22986033322568478
# Episode#:102000 reward:-157.0 best_reward:-110.0 epsilon:0.1885277082199074
# Episode#:108000 reward:-145.0 best_reward:-106.0 epsilon:0.1484722082143085
# Episode#:114000 reward:-145.0 best_reward:-87.0 epsilon:0.1105834582090125
# Episode#:120000 reward:-184.0 best_reward:-87.0 epsilon:0.07352991653716656
# Episode#:126000 reward:-155.0 best_reward:-87.0 epsilon:0.03874266653626047
# Episode#:132000 reward:-119.0 best_reward:-86.0 epsilon:0.004999999870112795
# Episode#:138000 reward:-142.0 best_reward:-86.0 epsilon:0.004999999870112795
# Episode#:144000 reward:-169.0 best_reward:-86.0 epsilon:0.004999999870112795
# Episode#:150000 reward:-143.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:156000 reward:-117.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:162000 reward:-136.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:168000 reward:-137.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:174000 reward:-118.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:180000 reward:-133.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:186000 reward:-139.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:192000 reward:-130.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:198000 reward:-112.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:204000 reward:-133.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:210000 reward:-111.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:216000 reward:-114.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:222000 reward:-143.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:228000 reward:-114.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:234000 reward:-112.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:240000 reward:-109.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:246000 reward:-197.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:252000 reward:-110.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:258000 reward:-134.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:264000 reward:-134.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:270000 reward:-148.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:276000 reward:-116.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:282000 reward:-200.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:288000 reward:-135.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:294000 reward:-113.0 best_reward:-85.0 epsilon:0.004999999870112795
# Episode#:299999 reward:-140.0 best_reward:-85.0 epsilon:0.004999999870112795

# %%
plt.ylabel('Steps\nper\nepisode', rotation=0, labelpad=50, fontsize='large')
plt.xlabel('Episode', fontsize='large')
plt.plot(steps_list)

# %%
avg_steps = 10
avg_steps_list = get_avg_steps_list(steps_list, avg_steps)
plt.ylabel('Steps\nper\nepisode\naveraged\nover\n{} runs'.format(avg_steps), rotation=0, labelpad=50, fontsize='large')
plt.xlabel('Episode', fontsize='large')
plt.plot(avg_steps_list)

# %%
avg_steps = 100
avg_steps_list = get_avg_steps_list(steps_list, avg_steps)
plt.ylabel('Steps\nper\nepisode\naveraged\nover\n{} runs'.format(avg_steps), rotation=0, labelpad=50, fontsize='large')
plt.xlabel('Episode', fontsize='large')
plt.plot(avg_steps_list)

# %% [markdown]
# ### 2.2. Test

# %%
env = gym.make('MountainCar-v0')
total_reward_list = list()
for _ in range(1000):
    total_reward = test(agent, env, learned_policy)
    total_reward_list.append(total_reward)
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
plt.ylabel('Total\nreward', rotation=0, labelpad=30, fontsize='large')
plt.xlabel('Test episode', fontsize='large')
plt.plot(total_reward_list)

# %%
max(total_reward_list), min(total_reward_list)
# Out:
# (-111.0, -160.0)
