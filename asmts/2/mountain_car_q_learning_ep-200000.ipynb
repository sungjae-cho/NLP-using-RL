# %% [markdown]
# # Assignment 2: Solve the Mountain Car Task

# %% [markdown]
# ## How to Do Assignment 2 (Official)
# - Solve the Mountain Car task in Gym environment.
# - Freely choose a control algorithm you prefer.
# - Study existing codes using the method you are following.
#   - [Mountain Car](https://github.com/Youngsam/youngsam.github.io/tree/master/codes/FunctionApprox/mountain_car)
# - Zip the **source code** and **result graph file**, and upload the file in ETL homework page (see the example in the lecture slide)
#
# **About the Result Graph**
# - x-axis: Episode
# - y-axis: Steps per episode (log scale. Averaged over 100 runs.)
# - You don’t need to test several parameters.
# - You don’t need to use log scale.
# - You better average the steps per episode for stable estimates (e.g., averaging over 10 runs).

# %% [markdown]
# ## References
# - [Original source](https://github.com/dennybritz/reinforcement-learning/tree/master/FA) of the given Mountain Car code.
# - [About MountainCar-v0](https://github.com/openai/gym/wiki/MountainCar-v0)

# %% [markdown]
# ## 1. Implementation of a Q-Learning Agent

# %%
"""
An easy-to-follow script to train, test and evaluate a Q-learning agent on the Mountain Car
problem using the OpenAI Gym.
This is part of the Book on "Getting started with OpenAI Gym"
Author: Praveen Palanisamy
"""
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

MAX_NUM_EPISODES = 200000
STEPS_PER_EPISODE = 200 #200 #  This is specific to MountainCar. May change with env
PRINT_PERIOD = MAX_NUM_EPISODES // 50 # unit: episodes
EPSILON_MIN = 0.005
max_num_steps = MAX_NUM_EPISODES * STEPS_PER_EPISODE
EPSILON_DECAY = 500 * EPSILON_MIN / max_num_steps
ALPHA = 0.05  # Learning rate
GAMMA = 0.98  # Discount factor
NUM_DISCRETE_BINS = 30  # Number of bins to Discretize each observation dim

class Q_Learner(object):
    def __init__(self, env):
        self.obs_shape = env.observation_space.shape
        self.obs_high = env.observation_space.high
        self.obs_low = env.observation_space.low
        self.obs_bins = NUM_DISCRETE_BINS  # Number of bins to Discretize each observation dim
        self.bin_width = (self.obs_high - self.obs_low) / self.obs_bins
        self.action_shape = env.action_space.n
        # Create a multi-dimensional array (aka. Table) to represent the
        # Q-values
        self.Q = np.zeros((self.obs_bins + 1, self.obs_bins + 1,
                           self.action_shape))  # (51 x 51 x 3)
        self.alpha = ALPHA  # Learning rate
        self.gamma = GAMMA  # Discount factor
        self.epsilon = 1.0
        

    def discretize(self, obs):
        return tuple(((obs - self.obs_low) / self.bin_width).astype(int))

    def get_action(self, obs):
        discretized_obs = self.discretize(obs)
        # Epsilon-Greedy action selection
        if self.epsilon > EPSILON_MIN:
            self.epsilon -= EPSILON_DECAY
        if np.random.random() > self.epsilon:
            return np.argmax(self.Q[discretized_obs])
        else:  # Choose a random action
            return np.random.choice([a for a in range(self.action_shape)])

    def learn(self, obs, action, reward, next_obs):
        discretized_obs = self.discretize(obs)
        discretized_next_obs = self.discretize(next_obs)
        td_target = reward + self.gamma * np.max(self.Q[discretized_next_obs])
        td_error = td_target - self.Q[discretized_obs][action]
        self.Q[discretized_obs][action] += self.alpha * td_error

def train(agent, env):
    best_reward = -float('inf')
    steps_list = list()
    
    for episode in range(MAX_NUM_EPISODES):
        done = False
        obs = env.reset()
        total_reward = 0.0
        steps = 0
        while not done:
            action = agent.get_action(obs)
            next_obs, reward, done, info = env.step(action)
            agent.learn(obs, action, reward, next_obs)
            obs = next_obs
            total_reward += reward
            steps = steps + 1
        if total_reward > best_reward:
            best_reward = total_reward
        
        if (episode % PRINT_PERIOD == 0) or (episode == MAX_NUM_EPISODES - 1):
            print("Episode#:{} reward:{} best_reward:{} epsilon:{}".format(episode,
                                         total_reward, best_reward, agent.epsilon))        
        
        steps_list.append(steps)
    # Return the trained policy
    return np.argmax(agent.Q, axis=2), steps_list


def test(agent, env, policy):
    done = False
    obs = env.reset()
    total_reward = 0.0
    while not done:
        action = policy[agent.discretize(obs)]
        next_obs, reward, done, info = env.step(action)
        obs = next_obs
        total_reward += reward
    return total_reward

def get_avg_steps_list(steps_list, steps):
    avg_steps_list = list()
    for i in range(len(steps_list) - steps + 1):
        mean = sum(steps_list[i:(i+steps)]) / steps
        avg_steps_list.append(mean)
    return avg_steps_list

# %% [markdown]
# ## 2. Visualization

# %% [markdown]
# ### 2.1. Training: Q-Learning

# %%
env = gym.make('MountainCar-v0')
agent = Q_Learner(env)
learned_policy, steps_list = train(agent, env)
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode#:0 reward:-200.0 best_reward:-200.0 epsilon:0.9999875000000094
# Episode#:4000 reward:-200.0 best_reward:-200.0 epsilon:0.9499875000374294
# Episode#:8000 reward:-200.0 best_reward:-200.0 epsilon:0.8999875000748494
# Episode#:12000 reward:-200.0 best_reward:-200.0 epsilon:0.8499875001122694
# Episode#:16000 reward:-200.0 best_reward:-200.0 epsilon:0.7999875001496894
# Episode#:20000 reward:-200.0 best_reward:-200.0 epsilon:0.7499875001871095
# Episode#:24000 reward:-200.0 best_reward:-200.0 epsilon:0.6999875002245295
# Episode#:28000 reward:-200.0 best_reward:-200.0 epsilon:0.6499875002619495
# Episode#:32000 reward:-200.0 best_reward:-156.0 epsilon:0.600008312799354
# Episode#:36000 reward:-200.0 best_reward:-150.0 epsilon:0.5501013753367043
# Episode#:40000 reward:-200.0 best_reward:-150.0 epsilon:0.5005223128738093
# Episode#:44000 reward:-200.0 best_reward:-122.0 epsilon:0.45180018786746295
# Episode#:48000 reward:-200.0 best_reward:-122.0 epsilon:0.40412381286079885
# Episode#:52000 reward:-200.0 best_reward:-122.0 epsilon:0.35781825035432635
# Episode#:56000 reward:-162.0 best_reward:-119.0 epsilon:0.3129503128480548
# Episode#:60000 reward:-153.0 best_reward:-116.0 epsilon:0.26886925034189324
# Episode#:64000 reward:-152.0 best_reward:-113.0 epsilon:0.22604950033590798
# Episode#:68000 reward:-189.0 best_reward:-109.0 epsilon:0.1856397503302596
# Episode#:72000 reward:-149.0 best_reward:-109.0 epsilon:0.1455312503246533
# Episode#:76000 reward:-158.0 best_reward:-102.0 epsilon:0.10723756282324474
# Episode#:80000 reward:-95.0 best_reward:-95.0 epsilon:0.0671647503265414
# Episode#:84000 reward:-117.0 best_reward:-95.0 epsilon:0.03197575032604741
# Episode#:88000 reward:-151.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:92000 reward:-134.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:96000 reward:-143.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:100000 reward:-122.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:104000 reward:-137.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:108000 reward:-137.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:112000 reward:-119.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:116000 reward:-120.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:120000 reward:-141.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:124000 reward:-152.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:128000 reward:-134.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:132000 reward:-135.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:136000 reward:-137.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:140000 reward:-137.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:144000 reward:-113.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:148000 reward:-113.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:152000 reward:-140.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:156000 reward:-142.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:160000 reward:-139.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:164000 reward:-112.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:168000 reward:-163.0 best_reward:-95.0 epsilon:0.004999937826433968
# Episode#:172000 reward:-141.0 best_reward:-91.0 epsilon:0.004999937826433968
# Episode#:176000 reward:-111.0 best_reward:-91.0 epsilon:0.004999937826433968
# Episode#:180000 reward:-149.0 best_reward:-90.0 epsilon:0.004999937826433968
# Episode#:184000 reward:-112.0 best_reward:-90.0 epsilon:0.004999937826433968
# Episode#:188000 reward:-111.0 best_reward:-90.0 epsilon:0.004999937826433968
# Episode#:192000 reward:-112.0 best_reward:-88.0 epsilon:0.004999937826433968
# Episode#:196000 reward:-114.0 best_reward:-88.0 epsilon:0.004999937826433968
# Episode#:199999 reward:-110.0 best_reward:-88.0 epsilon:0.004999937826433968

# %%
plt.ylabel('Steps\nper\nepisode', rotation=0, labelpad=50, fontsize='large')
plt.xlabel('Episode', fontsize='large')
plt.plot(steps_list)

# %%
avg_steps = 10
avg_steps_list = get_avg_steps_list(steps_list, avg_steps)
plt.ylabel('Steps\nper\nepisode\naveraged\nover\n{} runs'.format(avg_steps), rotation=0, labelpad=50, fontsize='large')
plt.xlabel('Episode', fontsize='large')
plt.plot(avg_steps_list)

# %%
avg_steps = 100
avg_steps_list = get_avg_steps_list(steps_list, avg_steps)
plt.ylabel('Steps\nper\nepisode\naveraged\nover\n{} runs'.format(avg_steps), rotation=0, labelpad=50, fontsize='large')
plt.xlabel('Episode', fontsize='large')
plt.plot(avg_steps_list)

# %% [markdown]
# ### 2.2. Test

# %%
env = gym.make('MountainCar-v0')
total_reward_list = list()
for _ in range(1000):
    total_reward = test(agent, env, learned_policy)
    total_reward_list.append(total_reward)
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
plt.ylabel('Total\nreward', rotation=0, labelpad=30, fontsize='large')
plt.xlabel('Test episode', fontsize='large')
plt.plot(total_reward_list)

# %%
max(total_reward_list), min(total_reward_list)
# Out:
# (-110.0, -155.0)
